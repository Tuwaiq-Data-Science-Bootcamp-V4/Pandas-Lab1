# %%
import pandas as pd

# %% [markdown]
# ## Q1: Create a Series with indexes = 1, 2, 3 and has three names.

# %%
names = pd.Series({1:"Mohammed", 2:"Fahad", 3:"Saud"})
names
# Out:
# 1    Mohammed
# 2       Fahad
# 3        Saud
# dtype: object

# %% [markdown]
# ## Q2: Change indexes to 11, 12, 13.

# %%
names.index = [11,12,13]
names
# Out:
# 11    Mohammed
# 12       Fahad
# 13        Saud
# dtype: object

# %% [markdown]
# ## Q3: Retrieve First and second elements.

# %%
names[0:2]
# Out:
# 11    Mohammed
# 12       Fahad
# dtype: object

# %% [markdown]
# ## Q4: Add duplicate elements, then remove the duplication.

# %%
x = pd.Series({14:"Mohammed"})
names = names.append(x)
print(names)
print("-----------------------------")
names = names.drop_duplicates()
print(names)
# Out:
# 11    Mohammed
# 12       Fahad
# 13        Saud
# 14    Mohammed
# 14    Mohammed
# 14    Mohammed
# 14    Mohammed
# dtype: object
# -----------------------------
# 11    Mohammed
# 12       Fahad
# 13        Saud
# dtype: object
# C:\Users\mabal\AppData\Local\Temp\ipykernel_12612\1854034901.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   names = names.append(x)

# %% [markdown]
# ## Q5: Create a Students DataFrame has three columns (ID, Name, GPA).

# %%
 students = pd.DataFrame({"ID":[1,2,3],
                        "Name":["Mohammed","Fahad","Saud"],
                        "GPA":[4.5,3.78,2.80]})
students
# Out:
#    ID      Name   GPA
# 0   1  Mohammed  4.50
# 1   2     Fahad  3.78
# 2   3      Saud  2.80

# %% [markdown]
# ## Q6: Read educ_figdp_1_Data.csv file and print the head.

# %%
student1 = pd.read_csv("educ_figdp_1_Data.csv")
student1.head()
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e
# 4  Total public expenditure on education as % of ...  4.95                  e

# %% [markdown]
# ## Q7: Give an example shows the difference between loc and slicing?
# **Note:**
# - loc use the index labels as references.
# - slice use the position as references.

# %%
student1[0:5]
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e
# 4  Total public expenditure on education as % of ...  4.95                  e

# %%
student1.loc[0:5]
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
# 5  2005  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e
# 4  Total public expenditure on education as % of ...  4.95                  e
# 5  Total public expenditure on education as % of ...  4.92                  e
