# %%
import pandas as pd

# %% [markdown]
# ## Q1: Create a Series with indexes = 1, 2, 3 and has three names.

# %%
s =pd.Series(["Alaa","sara","Haya"],index=[1,2,3])
s
# Out:
# 1    Alaa
# 2    sara
# 3    Haya
# dtype: object

# %% [markdown]
# ## Q2: Change indexes to 11, 12, 13.

# %%
# change the indexes
s.index = [11, 12, 13]
s
# Out:
# 11    Alaa
# 12    sara
# 13    Haya
# dtype: object

# %% [markdown]
# ## Q3: Retrieve First and second elements.

# %%
s[:2]
# Out:
# 11    Alaa
# 12    sara
# dtype: object

# %% [markdown]
# ## Q4: Add duplicate elements, then remove the duplication.

# %%
s2=pd.Series(["Sara"],index=[1])
s2
s.append(s2)
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_2072\1314014474.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(s2)
# 11    Alaa
# 12    sara
# 13    Haya
# 1     Sara
# dtype: object

# %%
s.drop_duplicates()
# Out:
# 11    Alaa
# 12    sara
# 13    Haya
# dtype: object

# %% [markdown]
# ## Q5: Create a Students DataFrame has three columns (ID, Name, GPA).

# %%
  
 Stu ={
     'ID':[11 ,22 ,33] ,
     'Name':['Maha','Amal' ,'Sara'] ,
     'GPA':[4 ,4.5 , 3.5]
 }
Stu_=pd.DataFrame(Stu ,columns=['ID','Name','GPA'])
Stu_
# Out:
#   Cell In[23], line 3
#     Stu={
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Q6: Read educ_figdp_1_Data.csv file and print the head.

# %%
re =pd.read_csv("educ_figdp_1_Data.csv")
re
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# 379  Total public expenditure on education as % of ...  5.90
# 380  Total public expenditure on education as % of ...  6.10
# 381  Total public expenditure on education as % of ...  6.81
# 382  Total public expenditure on education as % of ...  6.85
# 383  Total public expenditure on education as % of ...  6.76
#
#     Flag and Footnotes
# 0                  NaN
# 1                  NaN
# 2                    e
# 3                    e
# 4                    e
# ..                 ...
# 379                NaN
# 380                NaN
# 381                NaN
# 382                NaN
# 383                NaN
#
# [384 rows x 5 columns]

# %% [markdown]
# ## Q7: Give an example shows the difference between loc and slicing?
# **Note:**
# - loc use the index labels as references.
# - slice use the position as references.

# %%
re.loc[:3]
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e

# %%
re[:3]
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
